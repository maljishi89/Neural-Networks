# %% [markdown]
# Mujtaba Aljishi. ID# 201690160

# %% [markdown]
# # Homework #2

# %% [markdown]
# We would like to design a MLP neural network to classify points whether they are inside the blue shape
# given below or not: Note that the coordinates of the points on the given shape are: (-8,0), (-4,4), (-4,-4),
# (0,0), (4,4), (4,-4), (8,0).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# i. Design an MLP to classify the given decision boundary, assuming simple perceptron: 𝑜𝑢𝑡𝑝𝑢𝑡 =
# 1 𝑖𝑓 Σ𝑖 𝑤𝑖𝑥𝑖 + 𝑏𝑖 ≥ 0. Clearly show the used weights and biases. (10 points)

# %% [markdown]
# we find the lines of this graph
# ![image.png](attachment:image.png)
# here is a link for the image if it does not work
# https://i.imgur.com/EtkXb7L.png
#
# I also uploaded the img with the homework

# %% [markdown]
# We have two common lines.<br>
#
# <b>Left graph:</b><br>
#
# Points: (-8,0) & (-4, -4)<br>
# x2 = ((-8- -4)/ (0-4)) x1 +c<br>
# x2 = -x1 +c, we substitute by -8 for x1 and 0 for x2 we get 0 = 8 + c -> c = -8<br>
# we get: x2 = -x1 -8 -> <br>
# 0 = -x1 -x2 -8<br>
# we do the same thing to get the rest of equations.<br>
# Points: (-8,0) & (-4, 4)<br>
# x2 = x1 + 8 -><br>
# 0 = x1 -x2 +8<br>
# Points: (-4, 4) & (0, 0)<br>
# x2 = -x1 <br>
# 0 = -x1 -x2<br>
# Points: (-4, -4) & (0, 0)<br>
# x2 = x1<br>
# 0 = x1 -x2<br>
#
# <b>right graph:</b><br>
#
# Points: (8,0) & (4, -4)<br>
# x2 = x1 -8<br>
# 0 = x1 -x2 -8<br>
#
# Points: (8,0) & (4, 4)<br>
# x2 = -x1 +8<br>
# 0 = -x2 -x1 +8<br>
# Points: (4,4) & (0, 0)<br>
# x2 = x1<br>
# Points: (4, -4) & (0, 0)<br>
# x2 = -x1<br>
#
# <b> Common lines are 0 = -x1 -x2 and 0 = x1 -x2 </b><br>
# Then we AND them. Since we have two common equation. So we have 6 perceptron at layer 2 and 2 in layer 3.<br>
# now let’s represent these equations in the graph<br>
#
# ![image.png](attachment:image.png)
# here is a link to the image if it does not work
# https://i.imgur.com/SwON8vU.png
#
# I also uploaded the img with the homework

# %% [markdown]
# As we can see when we identifiy the boundery, by drawing lines over it, of the shape we will have 8 boundery.

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ii. Model your designed MLP in (i) using the derived weights and biases. (5 points)

# %% [markdown]
# <b>We can easily simply represent our equations for the graph using these equation --> |x-4| + |y| = 4 and |x+4| + |y| = 4, but I will use our equations above

# %%
def sample_points(n):
    
    x1 = np.random.uniform(low=-10,high=10,size=n).reshape(-1,1) 
    x2 = np.random.uniform(low=-6,high=6,size=n).reshape(-1,1)
    #I first solve it using this equation that I came with then I used our above equations to solve it with.
    #If it is on the boundery of these equations --> |x-4| + |y| = 4 and |x+4| + |y| = 4, it gives us one
    y1 = ((np.absolute(x1-4) + np.absolute(x2)<4) | (np.absolute(x1+4) + np.absolute(x2)<4) ).astype(int).reshape(-1)
    # if it is on any boundery of the two shapes, it gives us one.
    #y1 = ( (((-x1 -x2)< 8 )& ((x2 +x1)< 0) & ((x2 -x1)< 8 )& ((x2 - x1)> 0)) | (((x2-x1)> -8 )& ((x2 +x1)> 0) & ((x2 +x1)< 8 )& ((x2 - x1)< 0)) ).astype(int).reshape(-1)
    x_simple = np.concatenate([x1,x2],axis=1)
    return x_simple,y1

# %% [markdown]
# iii. Generate a training set of 10,000 samples, validation test of 500 samples, and test set of 500
# samples. The x-axis ranges from -10 to 10 and the y-axis ranges from -6 to 6. Your generated
# samples should be within this boundary. (5 points)

# %%
# Generate the data
trainx,trainy = sample_points(10000)
valx,valy = sample_points(500)
testx,testy = sample_points(500)
print(trainx.shape,trainy.shape)
# Out:
# (10000, 2) (10000,)

# %% [markdown]
# iv. Test your model in (ii) using the generated training, validation, and test sets. You should get 100%
# accuracy. Plotting the training set should show a figure similar to the one below. (5 points)

# %% [markdown]
# v. Build an MLP network with 2 inputs, a single hidden layer with 8 neurons, and 2 outputs using
# ReLU activation function for the hidden layer. Train your network using SGD, with learning rate
# = 0.01, for 10,000 iterations, and using nn.CrossEntropyLoss(). Report the training and validation
# losses and training and validation accuracies. Also plot the classification results of the test samples.
# You should get a figure similar the one shown below. (10 points)

# %%
def generate_single_hidden_MLP(n_hidden_neurons):
    return nn.Sequential(nn.Linear(2,n_hidden_neurons),nn.ReLU(),nn.Linear(n_hidden_neurons,2))
model1 = generate_single_hidden_MLP(8)

# %%
trainx = torch.from_numpy(trainx).float()
valx = torch.from_numpy(valx).float()
testx = torch.from_numpy(testx).float()
trainy = torch.from_numpy(trainy).long()
valy = torch.from_numpy(valy).long()
testy = torch.from_numpy(testy).long()

# %% [markdown]
# training

# %%
def training_routine(net,dataset,n_iters,gpu):
    # organize the data
    train_data,train_labels,val_data,val_labels = dataset
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(net.parameters(),lr=0.01)
    
    # use the flag
    if gpu:
        train_data,train_labels = train_data.cuda(),train_labels.cuda()
        val_data,val_labels = val_data.cuda(),val_labels.cuda()
        net = net.cuda() # the network parameters also need to be on the gpu !
        print("Using GPU")
    else:
        print("Using CPU")
    for i in range(n_iters):
        # forward pass
        train_output = net(train_data)
        train_loss = criterion(train_output,train_labels)
        # backward pass and optimization
        train_loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
        # Once every 100 iterations, print statistics
        if i%100==0:
            print("At iteration",i)
            # compute the accuracy of the prediction
            train_prediction = train_output.cpu().detach().argmax(dim=1)
            train_accuracy = (train_prediction.numpy()==train_labels.numpy()).mean() 
            # Now for the validation set
            val_output = net(val_data)
            val_loss = criterion(val_output,val_labels)
            # compute the accuracy of the prediction
            val_prediction = val_output.cpu().detach().argmax(dim=1)
            val_accuracy = (val_prediction.numpy()==val_labels.numpy()).mean() 
            print("Training loss :",train_loss.cpu().detach().numpy())
            print("Training accuracy :",train_accuracy)
            print("Validation loss :",val_loss.cpu().detach().numpy())
            print("Validation accuracy :",val_accuracy)
    
    net = net.cpu()

# %%
dataset = trainx,trainy,valx,valy

# %%
gpu = False
gpu = gpu and torch.cuda.is_available() # to know if you actually can use the GPU

training_routine(model1,dataset,10000,gpu)
# Out:
# Using CPU
# At iteration 0
# Training loss : 1.6852483
# Training accuracy : 0.4363
# Validation loss : 1.500014
# Validation accuracy : 0.454
# At iteration 100
# Training loss : 0.5350444
# Training accuracy : 0.7367
# Validation loss : 0.5468442
# Validation accuracy : 0.73
# At iteration 200
# Training loss : 0.49973
# Training accuracy : 0.7367
# Validation loss : 0.5096829
# Validation accuracy : 0.73
# At iteration 300
# Training loss : 0.46809942
# Training accuracy : 0.734
# Validation loss : 0.47731474
# Validation accuracy : 0.728
# At iteration 400
# Training loss : 0.44193193
# Training accuracy : 0.7369
# Validation loss : 0.4504464
# Validation accuracy : 0.73
# At iteration 500
# Training loss : 0.42343178
# Training accuracy : 0.7432
# Validation loss : 0.43113145
# Validation accuracy : 0.74
# At iteration 600
# Training loss : 0.41025126
# Training accuracy : 0.7534
# Validation loss : 0.41788748
# Validation accuracy : 0.75
# At iteration 700
# Training loss : 0.40049648
# Training accuracy : 0.7655
# Validation loss : 0.40791714
# Validation accuracy : 0.758
# At iteration 800
# Training loss : 0.39273888
# Training accuracy : 0.7771
# Validation loss : 0.39994133
# Validation accuracy : 0.77
# At iteration 900
# Training loss : 0.38618448
# Training accuracy : 0.7873
# Validation loss : 0.3931744
# Validation accuracy : 0.776
# At iteration 1000
# Training loss : 0.38044623
# Training accuracy : 0.7982
# Validation loss : 0.3873134
# Validation accuracy : 0.78
# At iteration 1100
# Training loss : 0.375319
# Training accuracy : 0.8078
# Validation loss : 0.38209513
# Validation accuracy : 0.782
# At iteration 1200
# Training loss : 0.37065107
# Training accuracy : 0.8154
# Validation loss : 0.37733117
# Validation accuracy : 0.788
# At iteration 1300
# Training loss : 0.3663417
# Training accuracy : 0.82
# Validation loss : 0.37288442
# Validation accuracy : 0.792
# At iteration 1400
# Training loss : 0.36234573
# Training accuracy : 0.8254
# Validation loss : 0.36873364
# Validation accuracy : 0.792
# At iteration 1500
# Training loss : 0.35864598
# Training accuracy : 0.8294
# Validation loss : 0.36480355
# Validation accuracy : 0.8
# At iteration 1600
# Training loss : 0.35519707
# Training accuracy : 0.8329
# Validation loss : 0.36112586
# Validation accuracy : 0.804
# At iteration 1700
# Training loss : 0.3519413
# Training accuracy : 0.8353
# Validation loss : 0.35764235
# Validation accuracy : 0.81
# At iteration 1800
# Training loss : 0.34886557
# Training accuracy : 0.8379
# Validation loss : 0.35430837
# Validation accuracy : 0.818
# At iteration 1900
# Training loss : 0.34594533
# Training accuracy : 0.8396
# Validation loss : 0.35116634
# Validation accuracy : 0.824
# At iteration 2000
# Training loss : 0.34318727
# Training accuracy : 0.8412
# Validation loss : 0.3481604
# Validation accuracy : 0.826
# At iteration 2100
# Training loss : 0.34058508
# Training accuracy : 0.844
# Validation loss : 0.3452613
# Validation accuracy : 0.822
# At iteration 2200
# Training loss : 0.33812326
# Training accuracy : 0.8454
# Validation loss : 0.3424478
# Validation accuracy : 0.822
# At iteration 2300
# Training loss : 0.33577257
# Training accuracy : 0.8474
# Validation loss : 0.33968046
# Validation accuracy : 0.828
# At iteration 2400
# Training loss : 0.33354545
# Training accuracy : 0.8494
# Validation loss : 0.3370243
# Validation accuracy : 0.83
# At iteration 2500
# Training loss : 0.33141908
# Training accuracy : 0.851
# Validation loss : 0.33448184
# Validation accuracy : 0.832
# At iteration 2600
# Training loss : 0.32938573
# Training accuracy : 0.8528
# Validation loss : 0.33206794
# Validation accuracy : 0.834
# At iteration 2700
# Training loss : 0.3274265
# Training accuracy : 0.8543
# Validation loss : 0.32977122
# Validation accuracy : 0.836
# At iteration 2800
# Training loss : 0.32551354
# Training accuracy : 0.8556
# Validation loss : 0.3274778
# Validation accuracy : 0.838
# At iteration 2900
# Training loss : 0.3236589
# Training accuracy : 0.8571
# Validation loss : 0.3252551
# Validation accuracy : 0.84
# At iteration 3000
# Training loss : 0.32182324
# Training accuracy : 0.8579
# Validation loss : 0.32304707
# Validation accuracy : 0.84
# At iteration 3100
# Training loss : 0.32003906
# Training accuracy : 0.8597
# Validation loss : 0.32098055
# Validation accuracy : 0.846
# At iteration 3200
# Training loss : 0.31831828
# Training accuracy : 0.8613
# Validation loss : 0.31901467
# Validation accuracy : 0.844
# At iteration 3300
# Training loss : 0.31663853
# Training accuracy : 0.8622
# Validation loss : 0.31705758
# Validation accuracy : 0.846
# At iteration 3400
# Training loss : 0.3149827
# Training accuracy : 0.8623
# Validation loss : 0.31510654
# Validation accuracy : 0.846
# At iteration 3500
# Training loss : 0.31336507
# Training accuracy : 0.8625
# Validation loss : 0.31326544
# Validation accuracy : 0.846
# At iteration 3600
# Training loss : 0.31177098
# Training accuracy : 0.8635
# Validation loss : 0.31137016
# Validation accuracy : 0.846
# At iteration 3700
# Training loss : 0.31018046
# Training accuracy : 0.8649
# Validation loss : 0.30946586
# Validation accuracy : 0.844
# At iteration 3800
# Training loss : 0.3086041
# Training accuracy : 0.8651
# Validation loss : 0.30760878
# Validation accuracy : 0.846
# At iteration 3900
# Training loss : 0.30705047
# Training accuracy : 0.8659
# Validation loss : 0.3058034
# Validation accuracy : 0.85
# At iteration 4000
# Training loss : 0.30553865
# Training accuracy : 0.8671
# Validation loss : 0.3042571
# Validation accuracy : 0.852
# At iteration 4100
# Training loss : 0.3040498
# Training accuracy : 0.8678
# Validation loss : 0.3027738
# Validation accuracy : 0.85
# At iteration 4200
# Training loss : 0.3025948
# Training accuracy : 0.8681
# Validation loss : 0.3013545
# Validation accuracy : 0.854
# At iteration 4300
# Training loss : 0.301169
# Training accuracy : 0.8683
# Validation loss : 0.3000066
# Validation accuracy : 0.852
# At iteration 4400
# Training loss : 0.29980204
# Training accuracy : 0.8701
# Validation loss : 0.29871386
# Validation accuracy : 0.854
# At iteration 4500
# Training loss : 0.2984967
# Training accuracy : 0.8716
# Validation loss : 0.29748985
# Validation accuracy : 0.854
# At iteration 4600
# Training loss : 0.29723755
# Training accuracy : 0.8722
# Validation loss : 0.29634762
# Validation accuracy : 0.858
# At iteration 4700
# Training loss : 0.2960037
# Training accuracy : 0.8724
# Validation loss : 0.2952815
# Validation accuracy : 0.86
# At iteration 4800
# Training loss : 0.29476506
# Training accuracy : 0.8739
# Validation loss : 0.2942701
# Validation accuracy : 0.86
# At iteration 4900
# Training loss : 0.293559
# Training accuracy : 0.8751
# Validation loss : 0.29332778
# Validation accuracy : 0.862
# At iteration 5000
# Training loss : 0.29237002
# Training accuracy : 0.8759
# Validation loss : 0.29246557
# Validation accuracy : 0.862
# At iteration 5100
# Training loss : 0.2912119
# Training accuracy : 0.8761
# Validation loss : 0.29161114
# Validation accuracy : 0.862
# At iteration 5200
# Training loss : 0.29008523
# Training accuracy : 0.8765
# Validation loss : 0.29077786
# Validation accuracy : 0.862
# At iteration 5300
# Training loss : 0.28898087
# Training accuracy : 0.8775
# Validation loss : 0.29000482
# Validation accuracy : 0.864
# At iteration 5400
# Training loss : 0.28790325
# Training accuracy : 0.8774
# Validation loss : 0.2892818
# Validation accuracy : 0.862
# At iteration 5500
# Training loss : 0.28684306
# Training accuracy : 0.8773
# Validation loss : 0.28860426
# Validation accuracy : 0.862
# At iteration 5600
# Training loss : 0.28581485
# Training accuracy : 0.8773
# Validation loss : 0.28794864
# Validation accuracy : 0.86
# At iteration 5700
# Training loss : 0.2847968
# Training accuracy : 0.8772
# Validation loss : 0.28732726
# Validation accuracy : 0.86
# At iteration 5800
# Training loss : 0.28379974
# Training accuracy : 0.8778
# Validation loss : 0.28664213
# Validation accuracy : 0.86
# At iteration 5900
# Training loss : 0.2828176
# Training accuracy : 0.8779
# Validation loss : 0.28598088
# Validation accuracy : 0.856
# At iteration 6000
# Training loss : 0.28185233
# Training accuracy : 0.878
# Validation loss : 0.28532735
# Validation accuracy : 0.858
# At iteration 6100
# Training loss : 0.2809126
# Training accuracy : 0.8783
# Validation loss : 0.28466702
# Validation accuracy : 0.858
# At iteration 6200
# Training loss : 0.27998796
# Training accuracy : 0.8782
# Validation loss : 0.28401825
# Validation accuracy : 0.86
# At iteration 6300
# Training loss : 0.27908176
# Training accuracy : 0.8788
# Validation loss : 0.28337988
# Validation accuracy : 0.86
# At iteration 6400
# Training loss : 0.27818057
# Training accuracy : 0.8797
# Validation loss : 0.28275344
# Validation accuracy : 0.86
# At iteration 6500
# Training loss : 0.27729183
# Training accuracy : 0.8799
# Validation loss : 0.2821443
# Validation accuracy : 0.86
# At iteration 6600
# Training loss : 0.27641797
# Training accuracy : 0.8805
# Validation loss : 0.28155088
# Validation accuracy : 0.862
# At iteration 6700
# Training loss : 0.2755526
# Training accuracy : 0.8811
# Validation loss : 0.2809597
# Validation accuracy : 0.86
# At iteration 6800
# Training loss : 0.27469128
# Training accuracy : 0.8814
# Validation loss : 0.28036636
# Validation accuracy : 0.86
# At iteration 6900
# Training loss : 0.27382383
# Training accuracy : 0.8813
# Validation loss : 0.27978688
# Validation accuracy : 0.86
# At iteration 7000
# Training loss : 0.27296966
# Training accuracy : 0.8825
# Validation loss : 0.27922004
# Validation accuracy : 0.864
# At iteration 7100
# Training loss : 0.27212825
# Training accuracy : 0.8826
# Validation loss : 0.27866507
# Validation accuracy : 0.864
# At iteration 7200
# Training loss : 0.27129635
# Training accuracy : 0.8828
# Validation loss : 0.27811635
# Validation accuracy : 0.864
# At iteration 7300
# Training loss : 0.27047506
# Training accuracy : 0.8836
# Validation loss : 0.27757314
# Validation accuracy : 0.864
# At iteration 7400
# Training loss : 0.26966664
# Training accuracy : 0.8838
# Validation loss : 0.27704078
# Validation accuracy : 0.864
# At iteration 7500
# Training loss : 0.2688602
# Training accuracy : 0.8843
# Validation loss : 0.2765102
# Validation accuracy : 0.864
# At iteration 7600
# Training loss : 0.26806158
# Training accuracy : 0.8849
# Validation loss : 0.27599928
# Validation accuracy : 0.864
# At iteration 7700
# Training loss : 0.26727447
# Training accuracy : 0.8853
# Validation loss : 0.27550086
# Validation accuracy : 0.864
# At iteration 7800
# Training loss : 0.26649272
# Training accuracy : 0.8865
# Validation loss : 0.27501273
# Validation accuracy : 0.862
# At iteration 7900
# Training loss : 0.26571843
# Training accuracy : 0.8867
# Validation loss : 0.27449176
# Validation accuracy : 0.862
# At iteration 8000
# Training loss : 0.2649415
# Training accuracy : 0.8874
# Validation loss : 0.2739836
# Validation accuracy : 0.866
# At iteration 8100
# Training loss : 0.2641665
# Training accuracy : 0.8875
# Validation loss : 0.27350637
# Validation accuracy : 0.866
# At iteration 8200
# Training loss : 0.26340282
# Training accuracy : 0.8875
# Validation loss : 0.273028
# Validation accuracy : 0.866
# At iteration 8300
# Training loss : 0.26265585
# Training accuracy : 0.8881
# Validation loss : 0.27253416
# Validation accuracy : 0.866
# At iteration 8400
# Training loss : 0.26191962
# Training accuracy : 0.888
# Validation loss : 0.27202487
# Validation accuracy : 0.87
# At iteration 8500
# Training loss : 0.26118624
# Training accuracy : 0.8887
# Validation loss : 0.2715014
# Validation accuracy : 0.868
# At iteration 8600
# Training loss : 0.2604647
# Training accuracy : 0.8888
# Validation loss : 0.27097917
# Validation accuracy : 0.868
# At iteration 8700
# Training loss : 0.25975305
# Training accuracy : 0.8889
# Validation loss : 0.27045935
# Validation accuracy : 0.866
# At iteration 8800
# Training loss : 0.25904495
# Training accuracy : 0.8896
# Validation loss : 0.26994342
# Validation accuracy : 0.866
# At iteration 8900
# Training loss : 0.25833717
# Training accuracy : 0.8901
# Validation loss : 0.26942223
# Validation accuracy : 0.868
# At iteration 9000
# Training loss : 0.2576398
# Training accuracy : 0.8907
# Validation loss : 0.26892024
# Validation accuracy : 0.87
# At iteration 9100
# Training loss : 0.25694248
# Training accuracy : 0.8912
# Validation loss : 0.26841146
# Validation accuracy : 0.87
# At iteration 9200
# Training loss : 0.25625646
# Training accuracy : 0.8914
# Validation loss : 0.26792324
# Validation accuracy : 0.87
# At iteration 9300
# Training loss : 0.25557825
# Training accuracy : 0.8918
# Validation loss : 0.26747116
# Validation accuracy : 0.872
# At iteration 9400
# Training loss : 0.25490525
# Training accuracy : 0.8922
# Validation loss : 0.26703855
# Validation accuracy : 0.872
# At iteration 9500
# Training loss : 0.25423726
# Training accuracy : 0.8926
# Validation loss : 0.2666114
# Validation accuracy : 0.872
# At iteration 9600
# Training loss : 0.25357586
# Training accuracy : 0.893
# Validation loss : 0.2661847
# Validation accuracy : 0.872
# At iteration 9700
# Training loss : 0.25291142
# Training accuracy : 0.8933
# Validation loss : 0.26573834
# Validation accuracy : 0.868
# At iteration 9800
# Training loss : 0.2522491
# Training accuracy : 0.8937
# Validation loss : 0.26526383
# Validation accuracy : 0.868
# At iteration 9900
# Training loss : 0.2515912
# Training accuracy : 0.894
# Validation loss : 0.2648019
# Validation accuracy : 0.868

# %% [markdown]
# plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib as mpl




def print_model(model,datapoints, title):
    out = model(datapoints).argmax(dim=1).detach().numpy()
    green = datapoints.numpy()[np.where(out==1)]
    red = datapoints.numpy()[np.where(out==0)]

    points1 = [[-8, 0], [-4, 4], [0, 0], [-4, -4],[-8,0]]
    line1 = plt.Polygon(points1, closed=True, fill=None, edgecolor='b')
    
    points2 = [[8, 0], [4, -4], [0, 0], [4, 4],[8,0]]
    line2 = plt.Polygon(points2, closed=True, fill=None, edgecolor='b')
        
    
    fig, ax = plt.subplots() # note we must use plt.subplots, not plt.subplot
    # (or if you have an existing figure)
    # fig = plt.gcf()
    # ax = fig.gca()
    plt.xlim(-10, 10)
    plt.ylim(-6, 6)
    plt.title(title)
    pos_values = plt.scatter(x=green[:,0],y=green[:,1], color='g',)
    neg_values = plt.scatter(x=red[:,0],y=red[:,1], color='r',)
    ax.title.set_text = title
    ax.add_artist(pos_values)
    ax.add_artist(neg_values)
    ax.add_patch(line1)
    ax.add_patch(line2)

# %%
print_model(model1,testx,'model 1')

# %% [markdown]
# vi. Repeat step (v) using 50 neurons in the hidden layer. Compare the results you got with the model
# in (v). Also plot the classification results of the test samples. (5 points)

# %%
model2 = generate_single_hidden_MLP(50)
dataset = trainx,trainy,valx,valy

gpu = False
gpu = gpu and torch.cuda.is_available() # to know if you actually can use the GPU

training_routine(model2,dataset,10000,gpu)
# Out:
# Using CPU
# At iteration 0
# Training loss : 0.85076433
# Training accuracy : 0.595
# Validation loss : 0.7240375
# Validation accuracy : 0.644
# At iteration 100
# Training loss : 0.47334215
# Training accuracy : 0.7367
# Validation loss : 0.47880003
# Validation accuracy : 0.73
# At iteration 200
# Training loss : 0.4382298
# Training accuracy : 0.7367
# Validation loss : 0.44351262
# Validation accuracy : 0.73
# At iteration 300
# Training loss : 0.41285196
# Training accuracy : 0.7473
# Validation loss : 0.41812977
# Validation accuracy : 0.738
# At iteration 400
# Training loss : 0.39263922
# Training accuracy : 0.7603
# Validation loss : 0.3978472
# Validation accuracy : 0.758
# At iteration 500
# Training loss : 0.37589613
# Training accuracy : 0.7845
# Validation loss : 0.38099453
# Validation accuracy : 0.772
# At iteration 600
# Training loss : 0.36179766
# Training accuracy : 0.8035
# Validation loss : 0.3666911
# Validation accuracy : 0.79
# At iteration 700
# Training loss : 0.34974614
# Training accuracy : 0.8158
# Validation loss : 0.35432732
# Validation accuracy : 0.802
# At iteration 800
# Training loss : 0.3393347
# Training accuracy : 0.8279
# Validation loss : 0.34353337
# Validation accuracy : 0.816
# At iteration 900
# Training loss : 0.33022133
# Training accuracy : 0.8388
# Validation loss : 0.33397883
# Validation accuracy : 0.828
# At iteration 1000
# Training loss : 0.32217935
# Training accuracy : 0.847
# Validation loss : 0.32545274
# Validation accuracy : 0.832
# At iteration 1100
# Training loss : 0.31502196
# Training accuracy : 0.8525
# Validation loss : 0.3177923
# Validation accuracy : 0.834
# At iteration 1200
# Training loss : 0.30857977
# Training accuracy : 0.859
# Validation loss : 0.31087983
# Validation accuracy : 0.838
# At iteration 1300
# Training loss : 0.30274093
# Training accuracy : 0.8636
# Validation loss : 0.30465034
# Validation accuracy : 0.838
# At iteration 1400
# Training loss : 0.29723614
# Training accuracy : 0.8693
# Validation loss : 0.2989463
# Validation accuracy : 0.846
# At iteration 1500
# Training loss : 0.29202926
# Training accuracy : 0.8744
# Validation loss : 0.293344
# Validation accuracy : 0.85
# At iteration 1600
# Training loss : 0.28758097
# Training accuracy : 0.8773
# Validation loss : 0.2884447
# Validation accuracy : 0.856
# At iteration 1700
# Training loss : 0.2835789
# Training accuracy : 0.8808
# Validation loss : 0.28397596
# Validation accuracy : 0.856
# At iteration 1800
# Training loss : 0.2798912
# Training accuracy : 0.8832
# Validation loss : 0.27983654
# Validation accuracy : 0.858
# At iteration 1900
# Training loss : 0.27646843
# Training accuracy : 0.8865
# Validation loss : 0.2759771
# Validation accuracy : 0.862
# At iteration 2000
# Training loss : 0.27326667
# Training accuracy : 0.8879
# Validation loss : 0.2723672
# Validation accuracy : 0.862
# At iteration 2100
# Training loss : 0.27024943
# Training accuracy : 0.8902
# Validation loss : 0.26898223
# Validation accuracy : 0.864
# At iteration 2200
# Training loss : 0.26739562
# Training accuracy : 0.8918
# Validation loss : 0.2657575
# Validation accuracy : 0.868
# At iteration 2300
# Training loss : 0.26467466
# Training accuracy : 0.8931
# Validation loss : 0.26268524
# Validation accuracy : 0.87
# At iteration 2400
# Training loss : 0.26207742
# Training accuracy : 0.8948
# Validation loss : 0.25974053
# Validation accuracy : 0.878
# At iteration 2500
# Training loss : 0.2595773
# Training accuracy : 0.8979
# Validation loss : 0.25691375
# Validation accuracy : 0.878
# At iteration 2600
# Training loss : 0.2571709
# Training accuracy : 0.8991
# Validation loss : 0.25420144
# Validation accuracy : 0.88
# At iteration 2700
# Training loss : 0.2548372
# Training accuracy : 0.8999
# Validation loss : 0.25157848
# Validation accuracy : 0.88
# At iteration 2800
# Training loss : 0.25256294
# Training accuracy : 0.9018
# Validation loss : 0.24905391
# Validation accuracy : 0.882
# At iteration 2900
# Training loss : 0.25033498
# Training accuracy : 0.9026
# Validation loss : 0.24660042
# Validation accuracy : 0.884
# At iteration 3000
# Training loss : 0.24815777
# Training accuracy : 0.9034
# Validation loss : 0.24422227
# Validation accuracy : 0.89
# At iteration 3100
# Training loss : 0.24603322
# Training accuracy : 0.905
# Validation loss : 0.24191152
# Validation accuracy : 0.894
# At iteration 3200
# Training loss : 0.24394272
# Training accuracy : 0.9056
# Validation loss : 0.23966435
# Validation accuracy : 0.898
# At iteration 3300
# Training loss : 0.24188161
# Training accuracy : 0.907
# Validation loss : 0.23746058
# Validation accuracy : 0.9
# At iteration 3400
# Training loss : 0.23985137
# Training accuracy : 0.9088
# Validation loss : 0.23529561
# Validation accuracy : 0.902
# At iteration 3500
# Training loss : 0.2378488
# Training accuracy : 0.9098
# Validation loss : 0.23318136
# Validation accuracy : 0.902
# At iteration 3600
# Training loss : 0.23587693
# Training accuracy : 0.9105
# Validation loss : 0.23111933
# Validation accuracy : 0.902
# At iteration 3700
# Training loss : 0.23393372
# Training accuracy : 0.9114
# Validation loss : 0.22909339
# Validation accuracy : 0.908
# At iteration 3800
# Training loss : 0.23202634
# Training accuracy : 0.9123
# Validation loss : 0.22709547
# Validation accuracy : 0.91
# At iteration 3900
# Training loss : 0.23015894
# Training accuracy : 0.9134
# Validation loss : 0.22515327
# Validation accuracy : 0.91
# At iteration 4000
# Training loss : 0.22831626
# Training accuracy : 0.9141
# Validation loss : 0.2232303
# Validation accuracy : 0.91
# At iteration 4100
# Training loss : 0.22650468
# Training accuracy : 0.9151
# Validation loss : 0.22133304
# Validation accuracy : 0.91
# At iteration 4200
# Training loss : 0.2247241
# Training accuracy : 0.916
# Validation loss : 0.21947953
# Validation accuracy : 0.912
# At iteration 4300
# Training loss : 0.2229752
# Training accuracy : 0.9173
# Validation loss : 0.21766078
# Validation accuracy : 0.914
# At iteration 4400
# Training loss : 0.22125213
# Training accuracy : 0.9185
# Validation loss : 0.2158678
# Validation accuracy : 0.914
# At iteration 4500
# Training loss : 0.21954495
# Training accuracy : 0.9195
# Validation loss : 0.2140801
# Validation accuracy : 0.914
# At iteration 4600
# Training loss : 0.21785535
# Training accuracy : 0.9203
# Validation loss : 0.21231255
# Validation accuracy : 0.914
# At iteration 4700
# Training loss : 0.21618116
# Training accuracy : 0.9221
# Validation loss : 0.21054223
# Validation accuracy : 0.916
# At iteration 4800
# Training loss : 0.21453428
# Training accuracy : 0.923
# Validation loss : 0.20882076
# Validation accuracy : 0.916
# At iteration 4900
# Training loss : 0.21290882
# Training accuracy : 0.9236
# Validation loss : 0.2071349
# Validation accuracy : 0.916
# At iteration 5000
# Training loss : 0.21130612
# Training accuracy : 0.9243
# Validation loss : 0.2054814
# Validation accuracy : 0.92
# At iteration 5100
# Training loss : 0.20972107
# Training accuracy : 0.9249
# Validation loss : 0.20382692
# Validation accuracy : 0.922
# At iteration 5200
# Training loss : 0.20814756
# Training accuracy : 0.9256
# Validation loss : 0.20217657
# Validation accuracy : 0.924
# At iteration 5300
# Training loss : 0.20657898
# Training accuracy : 0.9261
# Validation loss : 0.20058429
# Validation accuracy : 0.926
# At iteration 5400
# Training loss : 0.20502771
# Training accuracy : 0.9268
# Validation loss : 0.19904853
# Validation accuracy : 0.926
# At iteration 5500
# Training loss : 0.20350322
# Training accuracy : 0.9279
# Validation loss : 0.1975336
# Validation accuracy : 0.93
# At iteration 5600
# Training loss : 0.20199706
# Training accuracy : 0.9284
# Validation loss : 0.19602814
# Validation accuracy : 0.932
# At iteration 5700
# Training loss : 0.20050842
# Training accuracy : 0.9295
# Validation loss : 0.19453855
# Validation accuracy : 0.932
# At iteration 5800
# Training loss : 0.19903623
# Training accuracy : 0.93
# Validation loss : 0.19307251
# Validation accuracy : 0.932
# At iteration 5900
# Training loss : 0.19758731
# Training accuracy : 0.9309
# Validation loss : 0.19163306
# Validation accuracy : 0.932
# At iteration 6000
# Training loss : 0.19615516
# Training accuracy : 0.9314
# Validation loss : 0.19020021
# Validation accuracy : 0.932
# At iteration 6100
# Training loss : 0.19473806
# Training accuracy : 0.9324
# Validation loss : 0.18877518
# Validation accuracy : 0.932
# At iteration 6200
# Training loss : 0.1933362
# Training accuracy : 0.9328
# Validation loss : 0.18736838
# Validation accuracy : 0.934
# At iteration 6300
# Training loss : 0.19194952
# Training accuracy : 0.9336
# Validation loss : 0.18598305
# Validation accuracy : 0.936
# At iteration 6400
# Training loss : 0.19057414
# Training accuracy : 0.9342
# Validation loss : 0.18463883
# Validation accuracy : 0.936
# At iteration 6500
# Training loss : 0.1892086
# Training accuracy : 0.9351
# Validation loss : 0.18330081
# Validation accuracy : 0.936
# At iteration 6600
# Training loss : 0.18785626
# Training accuracy : 0.9358
# Validation loss : 0.18197763
# Validation accuracy : 0.936
# At iteration 6700
# Training loss : 0.18651386
# Training accuracy : 0.9361
# Validation loss : 0.18065384
# Validation accuracy : 0.936
# At iteration 6800
# Training loss : 0.1851854
# Training accuracy : 0.937
# Validation loss : 0.1793326
# Validation accuracy : 0.936
# At iteration 6900
# Training loss : 0.18387054
# Training accuracy : 0.9378
# Validation loss : 0.17803173
# Validation accuracy : 0.938
# At iteration 7000
# Training loss : 0.18256746
# Training accuracy : 0.9391
# Validation loss : 0.17675118
# Validation accuracy : 0.94
# At iteration 7100
# Training loss : 0.1812768
# Training accuracy : 0.9391
# Validation loss : 0.17548649
# Validation accuracy : 0.942
# At iteration 7200
# Training loss : 0.17999928
# Training accuracy : 0.9398
# Validation loss : 0.17423254
# Validation accuracy : 0.942
# At iteration 7300
# Training loss : 0.17873217
# Training accuracy : 0.9401
# Validation loss : 0.173012
# Validation accuracy : 0.942
# At iteration 7400
# Training loss : 0.17748357
# Training accuracy : 0.9412
# Validation loss : 0.17180222
# Validation accuracy : 0.942
# At iteration 7500
# Training loss : 0.17625253
# Training accuracy : 0.9418
# Validation loss : 0.17059317
# Validation accuracy : 0.942
# At iteration 7600
# Training loss : 0.17503515
# Training accuracy : 0.942
# Validation loss : 0.16939624
# Validation accuracy : 0.944
# At iteration 7700
# Training loss : 0.17383151
# Training accuracy : 0.9425
# Validation loss : 0.16821325
# Validation accuracy : 0.946
# At iteration 7800
# Training loss : 0.1726449
# Training accuracy : 0.9432
# Validation loss : 0.1670591
# Validation accuracy : 0.946
# At iteration 7900
# Training loss : 0.17147596
# Training accuracy : 0.9437
# Validation loss : 0.16591989
# Validation accuracy : 0.946
# At iteration 8000
# Training loss : 0.17031577
# Training accuracy : 0.9442
# Validation loss : 0.16479355
# Validation accuracy : 0.946
# At iteration 8100
# Training loss : 0.16916566
# Training accuracy : 0.9449
# Validation loss : 0.16367905
# Validation accuracy : 0.946
# At iteration 8200
# Training loss : 0.16802536
# Training accuracy : 0.9453
# Validation loss : 0.16257748
# Validation accuracy : 0.946
# At iteration 8300
# Training loss : 0.16689594
# Training accuracy : 0.9459
# Validation loss : 0.16149357
# Validation accuracy : 0.946
# At iteration 8400
# Training loss : 0.16577512
# Training accuracy : 0.9464
# Validation loss : 0.16043827
# Validation accuracy : 0.946
# At iteration 8500
# Training loss : 0.16466132
# Training accuracy : 0.947
# Validation loss : 0.15939933
# Validation accuracy : 0.946
# At iteration 8600
# Training loss : 0.1635542
# Training accuracy : 0.9475
# Validation loss : 0.15837309
# Validation accuracy : 0.95
# At iteration 8700
# Training loss : 0.16245663
# Training accuracy : 0.9478
# Validation loss : 0.15736495
# Validation accuracy : 0.95
# At iteration 8800
# Training loss : 0.16136687
# Training accuracy : 0.9487
# Validation loss : 0.15638115
# Validation accuracy : 0.952
# At iteration 8900
# Training loss : 0.1602843
# Training accuracy : 0.9488
# Validation loss : 0.15541498
# Validation accuracy : 0.952
# At iteration 9000
# Training loss : 0.15920646
# Training accuracy : 0.9494
# Validation loss : 0.15446387
# Validation accuracy : 0.952
# At iteration 9100
# Training loss : 0.15813635
# Training accuracy : 0.9499
# Validation loss : 0.1535146
# Validation accuracy : 0.952
# At iteration 9200
# Training loss : 0.15707274
# Training accuracy : 0.9503
# Validation loss : 0.15258867
# Validation accuracy : 0.952
# At iteration 9300
# Training loss : 0.15601335
# Training accuracy : 0.9507
# Validation loss : 0.15168417
# Validation accuracy : 0.952
# At iteration 9400
# Training loss : 0.15496285
# Training accuracy : 0.9511
# Validation loss : 0.1507895
# Validation accuracy : 0.952
# At iteration 9500
# Training loss : 0.15392417
# Training accuracy : 0.9518
# Validation loss : 0.14988348
# Validation accuracy : 0.952
# At iteration 9600
# Training loss : 0.15289234
# Training accuracy : 0.9521
# Validation loss : 0.14894773
# Validation accuracy : 0.952
# At iteration 9700
# Training loss : 0.15186755
# Training accuracy : 0.9525
# Validation loss : 0.14799978
# Validation accuracy : 0.952
# At iteration 9800
# Training loss : 0.15084536
# Training accuracy : 0.9529
# Validation loss : 0.14705971
# Validation accuracy : 0.952
# At iteration 9900
# Training loss : 0.14982262
# Training accuracy : 0.9538
# Validation loss : 0.14613779
# Validation accuracy : 0.952

# %%
print_model(model2,testx,'model 2')
print_model(model1,testx,'model 1')

# %% [markdown]
# In model 1 we concluded in final iteration with this stat:<br>
#
# Training loss : 0.22863474<br>
# Training accuracy : 0.9092<br>
# Validation loss : 0.23296271<br>
# Validation accuracy : 0.904<br>
#
# In model 2 we concluded in final iteration with this stat:<br>
#
# Training loss : 0.14830276<br>
# Training accuracy : 0.9525<br>
# Validation loss : 0.15974909<br>
# Validation accuracy : 0.948<br>
#
# As you can see the training and validation accuracy are more accurate as we add more neurons for training.<br>
# The model becomes more accurate.<br>

# %% [markdown]
# vii. Build an MLP network with 2 inputs, first hidden layer with 8 neurons, second hidden layer of 2
# neurons and 2 outputs using ReLU activation function for the hidden layers. Train your network
# using SGD, with learning rate = 0.01, for 10,000 iterations, and using nn.CrossEntropyLoss().
# Report the training and validation losses and training and validation accuracies. Also plot the
# classification results of the test samples. Compare the obtained results against those obtained in (v)
# and (vi). (10 points)

# %%
def generate_double_hidden_MLP(n_hidden_neurons):
    return nn.Sequential(nn.Linear(2,n_hidden_neurons),nn.ReLU(),nn.Linear(n_hidden_neurons,n_hidden_neurons),nn.ReLU(),nn.Linear(n_hidden_neurons,2))

# %%
model3 = generate_double_hidden_MLP(8)

# %%
dataset = trainx,trainy,valx,valy

gpu = False
gpu = gpu and torch.cuda.is_available() # to know if you actually can use the GPU

training_routine(model3,dataset,10000,gpu)
# Out:
# Using CPU
# At iteration 0
# Training loss : 0.7175377
# Training accuracy : 0.5508
# Validation loss : 0.6484993
# Validation accuracy : 0.624
# At iteration 100
# Training loss : 0.44608745
# Training accuracy : 0.7428
# Validation loss : 0.44570976
# Validation accuracy : 0.738
# At iteration 200
# Training loss : 0.40688917
# Training accuracy : 0.7601
# Validation loss : 0.40775156
# Validation accuracy : 0.75
# At iteration 300
# Training loss : 0.37995008
# Training accuracy : 0.788
# Validation loss : 0.38158035
# Validation accuracy : 0.778
# At iteration 400
# Training loss : 0.35771728
# Training accuracy : 0.8125
# Validation loss : 0.35944027
# Validation accuracy : 0.788
# At iteration 500
# Training loss : 0.33777145
# Training accuracy : 0.8326
# Validation loss : 0.33935255
# Validation accuracy : 0.828
# At iteration 600
# Training loss : 0.31938294
# Training accuracy : 0.8482
# Validation loss : 0.32057497
# Validation accuracy : 0.84
# At iteration 700
# Training loss : 0.302387
# Training accuracy : 0.8618
# Validation loss : 0.30321035
# Validation accuracy : 0.852
# At iteration 800
# Training loss : 0.2867699
# Training accuracy : 0.874
# Validation loss : 0.28719634
# Validation accuracy : 0.858
# At iteration 900
# Training loss : 0.27246353
# Training accuracy : 0.8834
# Validation loss : 0.27240893
# Validation accuracy : 0.866
# At iteration 1000
# Training loss : 0.25939122
# Training accuracy : 0.8921
# Validation loss : 0.25916642
# Validation accuracy : 0.884
# At iteration 1100
# Training loss : 0.24757837
# Training accuracy : 0.9004
# Validation loss : 0.24744914
# Validation accuracy : 0.89
# At iteration 1200
# Training loss : 0.23700269
# Training accuracy : 0.9055
# Validation loss : 0.23703451
# Validation accuracy : 0.892
# At iteration 1300
# Training loss : 0.22745378
# Training accuracy : 0.9107
# Validation loss : 0.22758281
# Validation accuracy : 0.902
# At iteration 1400
# Training loss : 0.21874695
# Training accuracy : 0.9163
# Validation loss : 0.21894792
# Validation accuracy : 0.906
# At iteration 1500
# Training loss : 0.21074133
# Training accuracy : 0.9207
# Validation loss : 0.21094999
# Validation accuracy : 0.912
# At iteration 1600
# Training loss : 0.2033651
# Training accuracy : 0.9253
# Validation loss : 0.20355324
# Validation accuracy : 0.916
# At iteration 1700
# Training loss : 0.19652747
# Training accuracy : 0.9285
# Validation loss : 0.19672646
# Validation accuracy : 0.918
# At iteration 1800
# Training loss : 0.19009951
# Training accuracy : 0.9336
# Validation loss : 0.19035043
# Validation accuracy : 0.922
# At iteration 1900
# Training loss : 0.18402119
# Training accuracy : 0.9366
# Validation loss : 0.18436123
# Validation accuracy : 0.93
# At iteration 2000
# Training loss : 0.17826428
# Training accuracy : 0.9393
# Validation loss : 0.17873159
# Validation accuracy : 0.932
# At iteration 2100
# Training loss : 0.17282422
# Training accuracy : 0.9413
# Validation loss : 0.17353138
# Validation accuracy : 0.944
# At iteration 2200
# Training loss : 0.16766706
# Training accuracy : 0.9438
# Validation loss : 0.16865316
# Validation accuracy : 0.944
# At iteration 2300
# Training loss : 0.16277775
# Training accuracy : 0.9458
# Validation loss : 0.16396149
# Validation accuracy : 0.946
# At iteration 2400
# Training loss : 0.15813342
# Training accuracy : 0.9475
# Validation loss : 0.15946774
# Validation accuracy : 0.948
# At iteration 2500
# Training loss : 0.15370508
# Training accuracy : 0.9505
# Validation loss : 0.15519585
# Validation accuracy : 0.95
# At iteration 2600
# Training loss : 0.14946309
# Training accuracy : 0.9533
# Validation loss : 0.15106834
# Validation accuracy : 0.952
# At iteration 2700
# Training loss : 0.14539023
# Training accuracy : 0.9551
# Validation loss : 0.14713793
# Validation accuracy : 0.952
# At iteration 2800
# Training loss : 0.14148544
# Training accuracy : 0.9571
# Validation loss : 0.1433868
# Validation accuracy : 0.956
# At iteration 2900
# Training loss : 0.13773045
# Training accuracy : 0.9586
# Validation loss : 0.13982134
# Validation accuracy : 0.956
# At iteration 3000
# Training loss : 0.13412866
# Training accuracy : 0.9596
# Validation loss : 0.13643618
# Validation accuracy : 0.956
# At iteration 3100
# Training loss : 0.13066077
# Training accuracy : 0.9614
# Validation loss : 0.13320829
# Validation accuracy : 0.96
# At iteration 3200
# Training loss : 0.1273311
# Training accuracy : 0.963
# Validation loss : 0.13008302
# Validation accuracy : 0.962
# At iteration 3300
# Training loss : 0.12410738
# Training accuracy : 0.9646
# Validation loss : 0.12703475
# Validation accuracy : 0.964
# At iteration 3400
# Training loss : 0.120986655
# Training accuracy : 0.9659
# Validation loss : 0.124056004
# Validation accuracy : 0.966
# At iteration 3500
# Training loss : 0.118001394
# Training accuracy : 0.9668
# Validation loss : 0.12120211
# Validation accuracy : 0.968
# At iteration 3600
# Training loss : 0.11513584
# Training accuracy : 0.9677
# Validation loss : 0.11850583
# Validation accuracy : 0.97
# At iteration 3700
# Training loss : 0.11235836
# Training accuracy : 0.9687
# Validation loss : 0.11582748
# Validation accuracy : 0.97
# At iteration 3800
# Training loss : 0.10966912
# Training accuracy : 0.9701
# Validation loss : 0.11317842
# Validation accuracy : 0.97
# At iteration 3900
# Training loss : 0.10711123
# Training accuracy : 0.9716
# Validation loss : 0.11063923
# Validation accuracy : 0.974
# At iteration 4000
# Training loss : 0.104644835
# Training accuracy : 0.9733
# Validation loss : 0.10820442
# Validation accuracy : 0.974
# At iteration 4100
# Training loss : 0.10226513
# Training accuracy : 0.9741
# Validation loss : 0.10585597
# Validation accuracy : 0.974
# At iteration 4200
# Training loss : 0.09998195
# Training accuracy : 0.9761
# Validation loss : 0.103653066
# Validation accuracy : 0.974
# At iteration 4300
# Training loss : 0.09779637
# Training accuracy : 0.9772
# Validation loss : 0.1016009
# Validation accuracy : 0.976
# At iteration 4400
# Training loss : 0.095701545
# Training accuracy : 0.9783
# Validation loss : 0.09957385
# Validation accuracy : 0.976
# At iteration 4500
# Training loss : 0.093697965
# Training accuracy : 0.979
# Validation loss : 0.097664274
# Validation accuracy : 0.976
# At iteration 4600
# Training loss : 0.09179777
# Training accuracy : 0.9798
# Validation loss : 0.095821075
# Validation accuracy : 0.976
# At iteration 4700
# Training loss : 0.089940675
# Training accuracy : 0.9804
# Validation loss : 0.093997516
# Validation accuracy : 0.976
# At iteration 4800
# Training loss : 0.088115014
# Training accuracy : 0.9815
# Validation loss : 0.09222462
# Validation accuracy : 0.976
# At iteration 4900
# Training loss : 0.086427115
# Training accuracy : 0.9824
# Validation loss : 0.09056533
# Validation accuracy : 0.978
# At iteration 5000
# Training loss : 0.0848298
# Training accuracy : 0.9831
# Validation loss : 0.08903286
# Validation accuracy : 0.978
# At iteration 5100
# Training loss : 0.08330509
# Training accuracy : 0.9837
# Validation loss : 0.08756269
# Validation accuracy : 0.978
# At iteration 5200
# Training loss : 0.08185346
# Training accuracy : 0.984
# Validation loss : 0.08612439
# Validation accuracy : 0.982
# At iteration 5300
# Training loss : 0.080471426
# Training accuracy : 0.9852
# Validation loss : 0.084738605
# Validation accuracy : 0.986
# At iteration 5400
# Training loss : 0.07915602
# Training accuracy : 0.9856
# Validation loss : 0.08338135
# Validation accuracy : 0.986
# At iteration 5500
# Training loss : 0.07788665
# Training accuracy : 0.9859
# Validation loss : 0.082042225
# Validation accuracy : 0.986
# At iteration 5600
# Training loss : 0.07665537
# Training accuracy : 0.9863
# Validation loss : 0.08071736
# Validation accuracy : 0.988
# At iteration 5700
# Training loss : 0.07546311
# Training accuracy : 0.9867
# Validation loss : 0.079424806
# Validation accuracy : 0.988
# At iteration 5800
# Training loss : 0.074311815
# Training accuracy : 0.9876
# Validation loss : 0.07819752
# Validation accuracy : 0.99
# At iteration 5900
# Training loss : 0.07319925
# Training accuracy : 0.9878
# Validation loss : 0.07701425
# Validation accuracy : 0.992
# At iteration 6000
# Training loss : 0.07213959
# Training accuracy : 0.988
# Validation loss : 0.07592045
# Validation accuracy : 0.992
# At iteration 6100
# Training loss : 0.07112177
# Training accuracy : 0.9881
# Validation loss : 0.0748662
# Validation accuracy : 0.992
# At iteration 6200
# Training loss : 0.070142105
# Training accuracy : 0.9886
# Validation loss : 0.07384605
# Validation accuracy : 0.992
# At iteration 6300
# Training loss : 0.069199644
# Training accuracy : 0.9889
# Validation loss : 0.072859906
# Validation accuracy : 0.992
# At iteration 6400
# Training loss : 0.06828966
# Training accuracy : 0.9889
# Validation loss : 0.071903825
# Validation accuracy : 0.994
# At iteration 6500
# Training loss : 0.06740524
# Training accuracy : 0.9892
# Validation loss : 0.070986964
# Validation accuracy : 0.994
# At iteration 6600
# Training loss : 0.06654508
# Training accuracy : 0.9893
# Validation loss : 0.07009055
# Validation accuracy : 0.994
# At iteration 6700
# Training loss : 0.06571107
# Training accuracy : 0.9895
# Validation loss : 0.06921957
# Validation accuracy : 0.994
# At iteration 6800
# Training loss : 0.064897664
# Training accuracy : 0.9895
# Validation loss : 0.06838184
# Validation accuracy : 0.994
# At iteration 6900
# Training loss : 0.06410578
# Training accuracy : 0.9896
# Validation loss : 0.0675648
# Validation accuracy : 0.996
# At iteration 7000
# Training loss : 0.06334067
# Training accuracy : 0.9901
# Validation loss : 0.066772826
# Validation accuracy : 0.996
# At iteration 7100
# Training loss : 0.06260082
# Training accuracy : 0.9904
# Validation loss : 0.065987
# Validation accuracy : 0.996
# At iteration 7200
# Training loss : 0.061881866
# Training accuracy : 0.9905
# Validation loss : 0.06522765
# Validation accuracy : 0.996
# At iteration 7300
# Training loss : 0.06118647
# Training accuracy : 0.9906
# Validation loss : 0.06450846
# Validation accuracy : 0.996
# At iteration 7400
# Training loss : 0.060512103
# Training accuracy : 0.9905
# Validation loss : 0.063803665
# Validation accuracy : 0.996
# At iteration 7500
# Training loss : 0.059859157
# Training accuracy : 0.9906
# Validation loss : 0.06310964
# Validation accuracy : 0.996
# At iteration 7600
# Training loss : 0.05922487
# Training accuracy : 0.9909
# Validation loss : 0.062429283
# Validation accuracy : 0.996
# At iteration 7700
# Training loss : 0.05860877
# Training accuracy : 0.9909
# Validation loss : 0.06176105
# Validation accuracy : 0.996
# At iteration 7800
# Training loss : 0.058011036
# Training accuracy : 0.9911
# Validation loss : 0.061112236
# Validation accuracy : 0.996
# At iteration 7900
# Training loss : 0.057425767
# Training accuracy : 0.9911
# Validation loss : 0.060486276
# Validation accuracy : 0.996
# At iteration 8000
# Training loss : 0.056854982
# Training accuracy : 0.9911
# Validation loss : 0.059870385
# Validation accuracy : 0.996
# At iteration 8100
# Training loss : 0.056298498
# Training accuracy : 0.9914
# Validation loss : 0.059266772
# Validation accuracy : 0.996
# At iteration 8200
# Training loss : 0.05575984
# Training accuracy : 0.9914
# Validation loss : 0.058680307
# Validation accuracy : 0.996
# At iteration 8300
# Training loss : 0.055237774
# Training accuracy : 0.9915
# Validation loss : 0.058108166
# Validation accuracy : 0.996
# At iteration 8400
# Training loss : 0.05473035
# Training accuracy : 0.9917
# Validation loss : 0.05755005
# Validation accuracy : 0.996
# At iteration 8500
# Training loss : 0.05423489
# Training accuracy : 0.9918
# Validation loss : 0.056999765
# Validation accuracy : 0.996
# At iteration 8600
# Training loss : 0.05375221
# Training accuracy : 0.9918
# Validation loss : 0.056462377
# Validation accuracy : 0.996
# At iteration 8700
# Training loss : 0.053280488
# Training accuracy : 0.992
# Validation loss : 0.055929
# Validation accuracy : 0.996
# At iteration 8800
# Training loss : 0.05281955
# Training accuracy : 0.9921
# Validation loss : 0.055407964
# Validation accuracy : 0.996
# At iteration 8900
# Training loss : 0.052369084
# Training accuracy : 0.9921
# Validation loss : 0.054894824
# Validation accuracy : 0.996
# At iteration 9000
# Training loss : 0.051928222
# Training accuracy : 0.9922
# Validation loss : 0.054391805
# Validation accuracy : 0.996
# At iteration 9100
# Training loss : 0.051496565
# Training accuracy : 0.9922
# Validation loss : 0.053901426
# Validation accuracy : 0.996
# At iteration 9200
# Training loss : 0.05107406
# Training accuracy : 0.9922
# Validation loss : 0.053418107
# Validation accuracy : 0.996
# At iteration 9300
# Training loss : 0.050661
# Training accuracy : 0.9925
# Validation loss : 0.05294521
# Validation accuracy : 0.996
# At iteration 9400
# Training loss : 0.05025634
# Training accuracy : 0.9926
# Validation loss : 0.05247546
# Validation accuracy : 0.996
# At iteration 9500
# Training loss : 0.04985947
# Training accuracy : 0.9927
# Validation loss : 0.05201263
# Validation accuracy : 0.996
# At iteration 9600
# Training loss : 0.049470544
# Training accuracy : 0.9927
# Validation loss : 0.051559456
# Validation accuracy : 0.996
# At iteration 9700
# Training loss : 0.049088206
# Training accuracy : 0.9927
# Validation loss : 0.05110975
# Validation accuracy : 0.996
# At iteration 9800
# Training loss : 0.04871318
# Training accuracy : 0.9927
# Validation loss : 0.05066277
# Validation accuracy : 0.996
# At iteration 9900
# Training loss : 0.04834213
# Training accuracy : 0.9928
# Validation loss : 0.050220303
# Validation accuracy : 0.996

# %%
print_model(model3,testx,'model 3')
print_model(model2,testx,'model 2')

# %% [markdown]
# In model 3 we concluded in final iteration with this stat:<br>
#
# Training loss : 0.108602695<br>
# Training accuracy : 0.9678<br>
# Validation loss : 0.102672964<br>
# Validation accuracy : 0.974<br>
#
# In model 2 we concluded in final iteration with this stat:<br>
#
# Training loss : 0.14830276<br>
# Training accuracy : 0.9525<br>
# Validation loss : 0.15974909<br>
# Validation accuracy : 0.948<br>
#
# As you can see the training and validation accuracy are more accurate as we add more hidden layers for training.<br>
# The model becomes more accurate even with less neurons.<br>
